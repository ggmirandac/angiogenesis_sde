# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hit_35 = pd.read_csv('hit_time0_35.csv')
hit_75 = pd.read_csv('hit_time0_75.csv')    
fig, ax = plt.subplots()
sns.histplot(hit_35, ax=ax, label='35', cumulative=True)
sns.histplot(hit_75, ax=ax, label='75', cumulative=True)
# Out:
# <Axes: ylabel='Count'>
