# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
wall = 10
a0 = 9
dx = wall - 0 
dy = a0 
y = (x * dy / dx )/ a0
y = x / dx
y = x / wall
plt.plot(x, y, label='linear')
